# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv, set_option
from pandas.plotting import scatter_matrix
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import datetime

# %%
names=["id", "runtime", "Setting1", 'Setting2', 'Setting3', 'Tag1', 'Tag2', 'Tag3', 'Tag4', 
       'Tag5','Tag6', 'Tag7', 'Tag8', 'Tag9', 'Tag10', 'Tag11', 'Tag12', 'Tag13', 
       'Tag14', 'Tag15', 'Tag16', 'Tag17', 'Tag18', 'Tag19', 'Tag20', 'Tag21']

# %%
df = pd.read_csv('PM_test.txt', header=None, delimiter=r"\s+", names=names)

# %%
print(df.shape)
pd.set_option('display.max_columns', None)
# Out:
# (13096, 26)

# %%
df
# Out:
#        Asset id  runtime  Setting1  Setting2  Setting3    Tag1    Tag2  \
# 0             1        1    0.0023    0.0003     100.0  518.67  643.02
# 1             1        2   -0.0027   -0.0003     100.0  518.67  641.71
# 2             1        3    0.0003    0.0001     100.0  518.67  642.46
# 3             1        4    0.0042    0.0000     100.0  518.67  642.44
# 4             1        5    0.0014    0.0000     100.0  518.67  642.51
# ...         ...      ...       ...       ...       ...     ...     ...
# 13091       100      194    0.0049    0.0000     100.0  518.67  643.24
# 13092       100      195   -0.0011   -0.0001     100.0  518.67  643.22
# 13093       100      196   -0.0006   -0.0003     100.0  518.67  643.44
# 13094       100      197   -0.0038    0.0001     100.0  518.67  643.26
# 13095       100      198    0.0013    0.0003     100.0  518.67  642.95
#
#           Tag3     Tag4   Tag5   Tag6    Tag7     Tag8     Tag9  Tag10  Tag11  \
# ...

# %%
# Descrição dos dados
set_option('precision', 4)
df.describe()
# Out:
#          Asset id     runtime    Setting1    Setting2  Setting3        Tag1  \
# count  13096.0000  13096.0000  1.3096e+04  1.3096e+04   13096.0  1.3096e+04
# mean      51.5439     76.8365 -1.1179e-05  4.2379e-06     100.0  5.1867e+02
# std       28.2894     53.0577  2.2027e-03  2.9403e-04       0.0  6.0143e-11
# min        1.0000      1.0000 -8.2000e-03 -6.0000e-04     100.0  5.1867e+02
# 25%       28.0000     33.0000 -1.5000e-03 -2.0000e-04     100.0  5.1867e+02
# 50%       52.0000     69.0000  0.0000e+00  0.0000e+00     100.0  5.1867e+02
# 75%       76.0000    113.0000  1.5000e-03  3.0000e-04     100.0  5.1867e+02
# max      100.0000    303.0000  7.8000e-03  7.0000e-04     100.0  5.1867e+02
#
#              Tag2        Tag3        Tag4        Tag5        Tag6        Tag7  \
# count  13096.0000  13096.0000  13096.0000  1.3096e+04  13096.0000  13096.0000
# mean     642.4751   1588.0992   1404.7354  1.4620e+01     21.6097    553.7575
# ...

# %%
# Preparação dos dados
print('Null Values =', df.isnull().values.any())
